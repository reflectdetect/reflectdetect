# %%
import numpy as np

# %%
panel_properties_file = "../reflectance_panel_example_data.json"
geopackage_file = "../data/20240529_uav_multispectral_orthos_20m/20240529_tarps_locations.gpkg"
orthophotos_dir = "../data/20240529_uav_multispectral_orthos_20m/orthophotos"

# %%
import rasterio
from reflectdetect.utils.orthophoto import load_panel_locations, get_orthophoto_paths

panels = load_panel_locations(panel_properties_file, None)
panel_locations = load_panel_locations(geopackage_file, None)
orthophoto_paths = list(sorted(get_orthophoto_paths(orthophotos_dir, None)))
with rasterio.open(orthophoto_paths[0]) as orthophoto:
    number_of_bands = len(orthophoto.read())

assert len(panels) == len(panel_locations)
assert number_of_bands == len(panels[0]['bands'])

# %% [markdown]
# # 1. For each image extract each panel intensities for each band

# %%
intensities = np.zeros((len(orthophoto_paths), len(panel_locations), number_of_bands))
intensities.shape
# Out:
# (296, 3, 6)

# %%
from reflectdetect.utils.tests.test_orthophoto import SHRINK_FACTOR, NO_DATA_VALUE
from reflectdetect.utils.debug import show_intensities
from tqdm import tqdm
import numpy as np
from reflectdetect.utils.orthophoto import is_panel_in_orthophoto, extract_using_geolocation
from reflectdetect.pipeline import interpolate

# Extract intensities
for photo_index, orthophoto_path in enumerate(tqdm(orthophoto_paths)):
    with rasterio.open(orthophoto_path) as orthophoto:
        photo = orthophoto.read()
        for panel_index, panel in enumerate(panel_locations):
            if not is_panel_in_orthophoto(orthophoto_path, panel, SHRINK_FACTOR, NO_DATA_VALUE):
                intensities[photo_index][panel_index] = np.full(len(photo), np.nan)
                continue
            panel_intensities_per_band = extract_using_geolocation(orthophoto, panel, SHRINK_FACTOR, NO_DATA_VALUE, None)
            intensities[photo_index][panel_index] = panel_intensities_per_band

interpolated_intensities = intensities.copy()
for panel_index, panel in enumerate(panel_locations):
    for band_index in range(0, number_of_bands):
        interpolated_intensities[:, panel_index, band_index] = interpolate(intensities[:, panel_index, band_index])
show_intensities(intensities, interpolated_intensities)
# Out:
# 100%|██████████| 296/296 [00:30<00:00,  9.75it/s]

# %% [markdown]
# # Convert photos by photo and band

# %%
from reflectdetect.utils.panel import get_band_reflectance
from reflectdetect.pipeline import fit, convert

unconvertable_photos = []
converted_photos = []
for photo_index, orthophoto_path in enumerate(tqdm(orthophoto_paths)):
    converted_bands = []
    with rasterio.open(orthophoto_path) as orthophoto:
        photo = orthophoto.read()
    for band_index, band in enumerate(photo):
        intensities_of_panels = intensities[photo_index, :, band_index]
        if np.isnan(intensities_of_panels).any():
            unconvertable_photos.append((photo_index, band_index))
            converted_photos.append(None)
            break
        coeffs = fit(intensities_of_panels, get_band_reflectance(panels, band_index))
        converted_bands.append(convert(band, coeffs))
    else:
        # for loop did not break, all bands were converted
        converted_photos.append(converted_bands)
# Out:
# 100%|██████████| 296/296 [00:24<00:00, 12.10it/s]

# %%
import os
from pathlib import Path
from reflectdetect.utils.orthophoto import save_orthophotos
path = Path("./example_data")
os.makedirs(str(path), exist_ok=True)
save_orthophotos(path, orthophoto_paths, converted_photos)
# Out:
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1711, 'height': 1604, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322500000007721e-07, 0.0, 9.917434452175,
#        0.0, -1.1419499999862837e-07, 51.56494755632)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1711, 'height': 1604, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322500000007721e-07, 0.0, 9.917434452175,
#        0.0, -1.1419499999862837e-07, 51.56494755632)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 
)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1430, 'height': 1110, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999958207e-07, 0.0, 9.917535042699999,
#        0.0, -1.1419500000103883e-07, 51.564997802120004)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1412, 'height': 1119, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999942722e-07, 0.0, 9.917534859475,
#        0.0, -1.1419499999884214e-07, 51.565011619715)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1412, 'height': 1119, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999942722e-07, 0.0, 9.917534859475,
#        0.0, -1.1419499999884214e-07, 51.565011619715)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1400, 'height': 1094, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.832250000001677e-07, 0.0, 9.917538157525,
#        0.0, -1.1419499999926005e-07, 51.565020526925004)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1400, 'height': 1094, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.832250000001677e-07, 0.0, 9.917538157525,
#        0.0, -1.1419499999926005e-07, 51.565020526925004)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1090, 'height': 1366, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999995815e-07, 0.0, 9.917601186925,
#        0.0, -1.1419499999782413e-07, 51.565051016990004)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1090, 'height': 1366, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999995815e-07, 0.0, 9.917601186925,
#        0.0, -1.1419499999782413e-07, 51.565051016990004)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1212, 'height': 1484, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.832249999995144e-07, 0.0, 9.917598255324998,
#        0.0, -1.1419499999817464e-07, 51.565043365925)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1212, 'height': 1484, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.832249999995144e-07, 0.0, 9.917598255324998,
#        0.0, -1.1419499999817464e-07, 51.565043365925)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1360, 'height': 1588, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999968255e-07, 0.0, 9.917614928799999,
#        0.0, -1.141950000018531e-07, 51.565049075675)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1360, 'height': 1588, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999968255e-07, 0.0, 9.917614928799999,
#        0.0, -1.141950000018531e-07, 51.565049075675)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1371, 'height': 1062, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.83225000000499e-07, 0.0, 9.917607050125,
#        0.0, -1.1419500000223229e-07, 51.564981472235004)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1371, 'height': 1062, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.83225000000499e-07, 0.0, 9.917607050125,
#        0.0, -1.1419500000223229e-07, 51.564981472235004)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1378, 'height': 1086, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999983989e-07, 0.0, 9.91759257535,
#        0.0, -1.14194999998351e-07, 51.56496879659)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1378, 'height': 1086, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999983989e-07, 0.0, 9.91759257535,
#        0.0, -1.14194999998351e-07, 51.56496879659)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1377, 'height': 1084, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322500000011792e-07, 0.0, 9.91759330825,
#        0.0, -1.1419499999812164e-07, 51.564964571375)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1377, 'height': 1084, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322500000011792e-07, 0.0, 9.91759330825,
#        0.0, -1.1419499999812164e-07, 51.564964571375)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1370, 'height': 1082, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999948233e-07, 0.0, 9.917598072099999,
#        0.0, -1.1419499999789143e-07, 51.564950867975)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1370, 'height': 1082, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.8322499999948233e-07, 0.0, 9.917598072099999,
#        0.0, -1.1419499999789143e-07, 51.564950867975)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1375, 'height': 1085, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.832249999993833e-07, 0.0, 9.917593674699999,
#        0.0, -1.1419500000151081e-07, 51.564932482580005)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1375, 'height': 1085, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.832249999993833e-07, 0.0, 9.917593674699999,
#        0.0, -1.1419500000151081e-07, 51.564932482580005)}
# {'driver': 'GTiff', 'dtype': 'uint16', 'nodata': None, 'width': 1375, 'height': 1087, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.832249999993833e-07, 0.0, 9.917595506949999,
#        0.0, -1.1419500000173373e-07, 51.564925174100004)}
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': None, 'width': 1375, 'height': 1087, 'count': 6, 'crs': CRS.from_epsg(4326), 'transform': Affine(1.832249999993833e-07, 0.0, 9.917595506949999,
#        0.0, -1.1419500000173373e-07, 51.564925174100004)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 15
#      11 meta.update(
#      12     dtype=rasterio.float32,
#      13 )
#      14 print(meta)
# ---> 15 save(output_path, photo, meta)
#
# File ~\reflectdetect\src\orthophoto_utils.py:105, in save(output_path, band_images, meta)
#     103 with rasterio.open(output_path, 'w', **meta) as dst:
#     104     for band_index, band in enumerate(band_images):
# --> 105         dst.write_band(band_index+1, band)
#
# KeyboardInterrupt:
